# %% [markdown]
# ## Inversion using optimization scheme
#
# ### 2 Layers model

# %%
# %matplotlib widget

# %%
import pygimli as pg
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import mu_0
import time

import sys
sys.path.insert(1, '../../src')

from PlotModel import PlotModelCond_2lay, Plot3Models_2lay, PlotErrorSpace, PlotData, rmse_a
from EM1D import EMforward2lay, GlobalSearch, ErrorSpace

# %% [markdown]
# ### Load True Model

# %%
# Import the conductivities and thicknesses used to create the LU table
conds = np.load('../data/conds_samples.npy')
thick = np.load('../data/thick_samples.npy')

# Import true models and data 
model_true = np.load('../data/model_true_w.npy')

# Data array for all the 1D stitched models
data_true = np.load('../data/data_true_w.npy')

data_true_noise_2 = np.load('../data/data_true_noise2_w.npy')
data_true_noise_5 = np.load('../data/data_true_noise5_w.npy')
data_true_noise_10 = np.load('../data/data_true_noise10_w.npy')

# Load GS estimated models
#model_GS_All = np.load('../data/model_est_w.npy')
#model_GS_Q = np.load('../data/model_est_Q_w.npy')
#model_GS_IP = np.load('../data/model_est_IP_w.npy')
model_true_grid = np.load('../data/model_true_w_grid.npy')

# %%
sigmas_true = model_true[:,:2]
depths_true = np.zeros_like((model_true[:,1:]))
depths_true[:,1] = model_true[:,2]

# %%
PlotModelCond_2lay(sigmas_true, depths_true, depths_true)
plt.title('True Model')
plt.show()
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Optimization using Q + IP

# %%
# Create forward modeller class

class EMforward(pg.Modelling):
    def __init__(self):
        """Initialize the model."""
        super().__init__()        
    def response(self, x):
        sig1 = x[0]
        sig2 = x[1]
        thick1 = x[2]
        Z = EMforward2lay(sig1, sig2, thick1)                           
        return Z               
    def createStartModel(self, dataVals):
        thk_ini = [3]
        sig_ini =  [100/1000, 100/1000] # [1/100, 1/5] # # 
        x0 = sig_ini + thk_ini
        return np.array(x0)

# %%
# Initialize the forward modelling class
EMf = EMforward()

# Define inversion transformations
transData = pg.trans.TransLog() # log transformation for data
transModel = pg.trans.TransLog()  # log-transform ensures thk and res >0

# Create inversion
invEM = pg.Inversion()
invEM.setForwardOperator(EMf)

invEM.transModel = transModel
invEM.transData = transData

# %%
# Relative error array
error = 1e-3 # introduce here the error you want to test
relativeError = np.ones_like(data_true[0]) * error

# %%
# Start inversion

model_est = np.zeros_like(model_true)
#chi2hist = [] # empty array to store the chi2 history
#modelhist = [] # empty array to store the model history

npos = len(data_true)

starttime = time.time()
# Perform inversion for each 1D model per position in stitched section
for pos in range(npos):
    dataE = data_true[pos].copy()
    dataE *= np.random.randn(len(dataE)) * relativeError + 1.0
    model_est_pos = invEM.run(dataE, relativeError, verbose=False, lam=100, maxIter=40)
    #chi2hist.append(invEM.chi2History)
    #modelhist.append(invEM.modelHistory)
    model_est[pos] = model_est_pos
    
endtime = time.time() - starttime

print(endtime)
# Out:
# 14/08/23 - 11:39:09 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:10 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:11 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:12 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:13 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:14 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:14 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:15 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:16 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:17 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:18 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:18 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:19 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:20 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:21 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:21 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:22 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:23 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:24 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:25 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 16.58739686012268

# %%
# %time
model_est_pos = invEM.run(dataE, relativeError, verbose=False, lam=100, maxIter=40)
# Out:
# 14/08/23 - 11:39:35 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 35.3 µs

# %%
# Results of estimated model

sigmas_est = model_est[:,:2]
depth_est = np.zeros_like(depths_true)
depth_est[:,1] = model_est[:,2]

model_est_grid = PlotModelCond_2lay(sigmas_est, depth_est, depths_true)
RMSE_cond = rmse_a(np.log10(np.hstack(sigmas_true)), np.log10(np.hstack(sigmas_est)))
RMSE_thk = rmse_a(depth_est[:,1], depths_true[:,1])
plt.title('Optimization: [Q + IP]')
plt.text(0,9.5,' $\sigma$ RMSE %.3g' %(RMSE_cond*100) + '%' 
          +' \n $h$ RMSE %.3g' %(RMSE_thk*100) +'%', color='w')
plt.text(0,-0.5,'i)', color='k',fontsize=15)
plt.show()
plt.tight_layout()
#plt.savefig('../figures/Opt_EstModel_Q+IP_2Lay_noise10_flip')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()

error_est = np.abs((model_true_grid-model_est_grid)/model_true_grid)*100
cf = ax.imshow(np.log10(error_est).T, extent=[0,npos,10,0], vmin=0, vmax=2,
          cmap=plt.cm.get_cmap("RdBu_r", 8))
cbar = fig.colorbar(cf, ax=ax, label=r"Relative Error",  shrink=0.5)
cbar.set_ticks([0, 1, 2])
cbar.ax.set_yticklabels([ r"$1\,\%$",
                         r"$10\,\%$", r"$100\,\%$"])
plt.title('Relative Error [Q + IP]')
plt.text(0.1,-0.5,'l)', color='k',fontsize=15)
plt.xlabel('Horizontal distance [m]')
plt.ylabel('Depth [m]')
# Out:
# Text(0, 0.5, 'Depth [m]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#np.save('../data/model_est_pg_noise10_w', model_est)

# %% [markdown]
# ### Optimization using Q

# %%
# Create forward modeller class

class EMforward_Q(pg.Modelling):
    def __init__(self):
        """Initialize the model."""
        super().__init__()        
    def response(self, x):
        sig1 = x[0]
        sig2 = x[1]
        thick1 = x[2]
        Z = EMforward2lay(sig1, sig2, thick1)                           
        return Z[:9]               
    def createStartModel(self, dataVals):
        thk_ini = [3]
        sig_ini = [100/1000, 100/1000] #[1/5, 1/100] # 
        x0 = sig_ini + thk_ini
        return np.array(x0)

# %%
# Initialize the forward modelling class
EMf_Q = EMforward_Q()

# Define inversion transformations
transData = pg.trans.TransLog() # log transformation for data
transModel = pg.trans.TransLog()  # log-transform ensures thk and res >0

# Create inversion
invEM = pg.Inversion()
invEM.setForwardOperator(EMf_Q)

invEM.transModel = transModel
invEM.transData = transData

# Relative error array
error = 1e-3 # introduce here the error you want to test
relativeError = np.ones_like(data_true[0, :9]) * error

# Start inversion

model_est_Q = np.zeros_like(model_true)
#chi2hist = [] # empty array to store the chi2 history
#modelhist = [] # empty array to store the model history

npos = len(data_true)

# Perform inversion for each 1D model per position in stitched section
for pos in range(npos):
    dataE = data_true[pos,:9].copy()
    dataE *= np.random.randn(len(dataE)) * relativeError + 1.0
    model_est_pos = invEM.run(dataE, relativeError, verbose=False, lam=100, maxIter=40)
   # chi2hist.append(invEM.chi2History)
   # modelhist.append(invEM.modelHistory)
    model_est_Q[pos] = model_est_pos
# Out:
# 14/08/23 - 11:39:44 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:45 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:46 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:47 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:47 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:48 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:49 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:50 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:50 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:51 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:52 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:53 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:54 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:54 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:55 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:56 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:57 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:58 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:39:59 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:00 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]

# %%
# Results of estimated model

sigmas_est_Q = model_est_Q[:,:2]
depth_est_Q = np.zeros_like(depths_true)
depth_est_Q[:,1] = model_est_Q[:,2]

model_est_Q_grid = PlotModelCond_2lay(sigmas_est_Q, depth_est_Q, depths_true)
RMSE_cond = rmse_a(np.log10(np.hstack(sigmas_true)), np.log10(np.hstack(sigmas_est_Q)))
RMSE_thk = rmse_a(depth_est_Q[:,1], depths_true[:,1])
plt.title('Optimization: [Q]')
plt.text(0,9.5,' $\sigma$ RMSE %.3g' %(RMSE_cond*100) + '%' 
          +' \n $h$ RMSE %.3g' %(RMSE_thk*100) +'%', color='w')
plt.text(0,-0.5,'i)', color='k',fontsize=15)
plt.tight_layout()
#plt.savefig('../figures/Opt_EstModel_Q_2Lay_flip')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()

error_est = np.abs((model_true_grid-model_est_Q_grid)/model_true_grid)*100
cf = ax.imshow(np.log10(error_est).T, extent=[0,npos,10,0], vmin=0, vmax=2,
          cmap=plt.cm.get_cmap("RdBu_r", 8))
cbar = fig.colorbar(cf, ax=ax, label=r"Relative Error",  shrink=0.5)
cbar.set_ticks([0, 1, 2])
cbar.ax.set_yticklabels([ r"$1\,\%$",
                         r"$10\,\%$", r"$100\,\%$"])
plt.title('Relative Error [Q]')
plt.text(0.1,-0.5,'l)', color='k',fontsize=15)
plt.xlabel('Horizontal distance [m]')
plt.ylabel('Depth [m]')
# Out:
# Text(0, 0.5, 'Depth [m]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Optimization using IP

# %%
# Create forward modeller class

class EMforward_IP(pg.Modelling):
    def __init__(self):
        """Initialize the model."""
        super().__init__()        
    def response(self, x):
        sig1 = x[0]
        sig2 = x[1]
        thick1 = x[2]
        Z = EMforward2lay(sig1, sig2, thick1)                           
        return Z[9:]               
    def createStartModel(self, dataVals):
        thk_ini = [3]
        sig_ini = [100/1000, 100/1000] # [1/5, 1/100] #  
        x0 = sig_ini + thk_ini
        return np.array(x0)

# %%
# Initialize the forward modelling class
EMf_IP = EMforward_IP()

# Define inversion transformations
transData = pg.trans.TransLog() # log transformation for data
transModel = pg.trans.TransLog()  # log-transform ensures thk and res >0

# Create inversion
invEM = pg.Inversion()
invEM.setForwardOperator(EMf_IP)

invEM.transModel = transModel
invEM.transData = transData

# Relative error array
error = 1e-3 # introduce here the error you want to test
relativeError = np.ones_like(data_true[0, 9:]) * error

# Start inversion

model_est_IP = np.zeros_like(model_true)
#chi2hist = [] # empty array to store the chi2 history
#modelhist = [] # empty array to store the model history

npos = len(data_true)

# Perform inversion for each 1D model per position in stitched section
for pos in range(npos):
    dataE = data_true[pos,9:].copy()
    dataE *= np.random.randn(len(dataE)) * relativeError + 1.0
    model_est_pos = invEM.run(dataE, relativeError, verbose=False, lam=100, maxIter=40)
   # chi2hist.append(invEM.chi2History)
   # modelhist.append(invEM.modelHistory)
    model_est_IP[pos] = model_est_pos
# Out:
# 14/08/23 - 11:40:02 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:03 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:05 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:06 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:07 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:08 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:09 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:11 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:12 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:13 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:15 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:16 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:17 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:18 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:19 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:20 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:20 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:21 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:22 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]
# 14/08/23 - 11:40:23 - pyGIMLi - INFO - Created startmodel from forward operator: [0.1 0.1 3. ]

# %%
# Results of estimated model

sigmas_est_IP = model_est_IP[:,:2]
depth_est_IP = np.zeros_like(depths_true)
depth_est_IP[:,1] = model_est_IP[:,2]

model_est_IP_grid = PlotModelCond_2lay(sigmas_est_IP, depth_est_IP, depths_true)
RMSE_cond = rmse_a(np.log10(np.hstack(sigmas_true)), np.log10(np.hstack(sigmas_est_IP)))
RMSE_thk = rmse_a(depth_est_IP[:,1], depths_true[:,1])
plt.title('Optimization: [IP]')
plt.text(0,9.5,' $\sigma$ RMSE %.3g' %(RMSE_cond*100) + '%' 
          +' \n $h$ RMSE %.3g' %(RMSE_thk*100) +'%', color='w')
plt.text(0,-0.5,'j)', color='k',fontsize=15)
plt.tight_layout()
#plt.savefig('../figures/Opt_EstModel_IP_2Lay_flip')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()

error_est = np.abs((model_true_grid-model_est_IP_grid)/model_true_grid)*100
cf = ax.imshow(np.log10(error_est).T, extent=[0,npos,10,0], vmin=0, vmax=2,
          cmap=plt.cm.get_cmap("RdBu_r", 8))
cbar = fig.colorbar(cf, ax=ax, label=r"Relative Error",  shrink=0.5)
cbar.set_ticks([0, 1, 2])
cbar.ax.set_yticklabels([ r"$1\,\%$",
                         r"$10\,\%$", r"$100\,\%$"])
plt.title('Relative Error [IP]')
plt.text(0.1,-0.5,'m)', color='k',fontsize=15)
plt.xlabel('Horizontal distance [m]')
plt.ylabel('Depth [m]')
# Out:
# Text(0, 0.5, 'Depth [m]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Save estimated models

np.save('../data/model_est_pg_w', model_est)
np.save('../data/model_est_Q_pg_w', model_est_Q)
np.save('../data/model_est_IP_pg_w', model_est_IP)
